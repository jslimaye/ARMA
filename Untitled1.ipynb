# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
def parser(x):
    return pd.datetime.strptime(x, '%Y-%m-%d')

series = pd.read_csv('sales.csv', header=0, parse_dates=[0], index_col=0, date_parser=parser)

# %%
series.head()
# Out:
#             Sales of shampoo over a three year period
# Month
# 2001-01-01                                      266.0
# 2001-02-01                                      145.9
# 2001-03-01                                      183.1
# 2001-04-01                                      119.3
# 2001-05-01                                      180.3

# %%
# %matplotlib inline

# %%
series.plot()

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(series)

# %%
def arma(series,p,q):
        for
