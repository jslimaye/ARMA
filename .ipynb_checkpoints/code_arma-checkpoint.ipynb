# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
def parser(x):
    return pd.datetime.strptime(x, '%Y-%m')

df = pd.read_csv('air.csv',parse_dates=[0],date_parser=parser)

# %%
df.head()
# Out:
#        Month  Passengers
# 0 1949-01-01         112
# 1 1949-02-01         118
# 2 1949-03-01         132
# 3 1949-04-01         129
# 4 1949-05-01         121

# %%
# %matplotlib inline

# %%
df.Passengers.plot()

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(df.Passengers)

# %%
from ARMA import fixed_fit

# %%
global model
model = fixed_fit(list(df.Passengers.values))
print(model)
# Out:
# (-0.247579276043759, 1.7053923995649847)

# %%
def cal_moving_averages(y):
#calculate ei moving average for each point
    moving_avgs = list()
    for i in range(len(y)):
        e = np.mean(y[:i+1])
        moving_avgs.append(e)
    return moving_avgs

# %%
test = list(df.Passengers.values)[-10:]

# %%
#model
y = list(df.Passengers.values)[:-10]
for i in range(10):
    e = cal_moving_averages(y)
    y_n = model[0]*y[-1] + model[1]*e[-1]
    y.append(y_n)
    print(len(y))
    model = fixed_fit(y)
    
    print(model)
    print("predicted: ",y_n,"actual: ",test[i])
# Out:
# 135
# (-0.3701116844492026, 1.9016198305999923)
# predicted:  358.46345327277913 actual:  419
# 136
# (-0.3701116844492026, 1.9016198305999923)
# predicted:  371.8277137540507 actual:  461
# 137
# (-0.3701116844492026, 1.9016198305999923)
# predicted:  368.37097220607876 actual:  472
# 138
# (-0.37011168444920267, 1.901619830599992)
# predicted:  371.07015404526476 actual:  535
# 139
# (-0.3701116844492028, 1.9016198305999925)
# predicted:  371.50757420961884 actual:  622
# 140
# (-0.37011168444920434, 1.9016198305999945)
# predicted:  372.76741512141075 actual:  606
# 141
# (-0.37011168444920384, 1.9016198305999938)
# predicted:  373.7196704193994 actual:  508
# 142
# (-0.3701116844491969, 1.9016198305999845)
# predicted:  374.7784884014823 actual:  461
# 143
# (-0.3701116844491924, 1.901619830599978)
# predicted:  375.79216876569546 actual:  390
# 144
# (-0.37011168444920933, 1.9016198306000014)
# predicted:  376.81637685290946 actual:  432
