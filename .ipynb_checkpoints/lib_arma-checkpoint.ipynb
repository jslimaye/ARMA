# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot

def parser(x):
    return datetime.strptime(x, '%Y-%m-%d')
    
series = read_csv('sales.csv', header=0, parse_dates=[0], index_col=0, date_parser=parser)
print(series.head())
series.plot()
pyplot.show()
# Out:
#             Sales of shampoo over a three year period
# Month
# 2001-01-01                                      266.0
# 2001-02-01                                      145.9
# 2001-03-01                                      183.1
# 2001-04-01                                      119.3
# 2001-05-01                                      180.3

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(series)
pyplot.show()

# %%
from statsmodels.tsa.arima_model import ARIMA
#fit model
model = ARIMA(series, order=(5,0))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
# c:\users\jalaj\appdata\local\programs\python\python37\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
#                                           ARMA Model Results
# =====================================================================================================
# Dep. Variable:     Sales of shampoo over a three year period   No. Observations:                   36
# Model:                                            ARMA(5, 0)   Log Likelihood                -206.709
# Method:                                              css-mle   S.D. of innovations             72.628
# Date:                                       Thu, 14 Mar 2019   AIC                            427.419
# Time:                                               13:11:35   BIC                            438.503
# Sample:                                           01-01-2001   HQIC                           431.288
#                                                 - 12-01-2003
# ===================================================================================================================
#                                                       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                             379.4742    157.716      2.406      0.022      70.357     688.591
# ar.L1.Sales of shampoo over a three year period     0.0843      0.175      0.481      0.634      -0.259       0.428
# ar.L2.Sales of shampoo over a three year period     0.6566      0.175      3.757      0.001       0.314       0.999
# ar.L3.Sales of shampoo over a three year period     0.2505      0.206      1.215      0.234      -0.154       0.655
# ar.L4.Sales of shampoo over a three year period    -0.0406      0.190     -0.214      0.832      -0.413       0.332
# ar.L5.Sales of shampoo over a three year period     0.0097      0.192      0.051      0.960      -0.366       0.385
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0191           -0.0000j            1.0191           -0.0000
# AR.2           -1.4375           -0.8048j            1.6475           -0.4188
# AR.3           -1.4375           +0.8048j            1.6475            0.4188
# AR.4            3.0103           -5.2946j            6.0905           -0.1677
# AR.5            3.0103           +5.2946j            6.0905            0.1677
# -----------------------------------------------------------------------------

# %%
# plot residual errors
from pandas import DataFrame
residuals = DataFrame(model_fit.resid)
residuals.plot()
pyplot.show()

# %%
residuals.plot(kind='kde')
pyplot.show()

# %%
print(residuals.describe())
# Out:
#                 0
# count   36.000000
# mean    13.169322
# std     76.524092
# min   -139.363998
# 25%    -35.307542
# 50%     18.953737
# 75%     42.070720
# max    158.651869

# %%
from sklearn.metrics import mean_squared_error
X = series.values
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
	model = ARIMA(history, order=(1,0,1))
	model_fit = model.fit(disp=0)
	output = model_fit.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test[t]
	history.append(obs)
	print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-4ca42840a6d0> in <module>
#       6 predictions = list()
#       7 for t in range(len(test)):
# ----> 8         model = ARIMA(history, order=(1,0,1))
#       9         model_fit = model.fit(disp=0)
#      10         output = model_fit.forecast()
#
# NameError: name 'ARIMA' is not defined
